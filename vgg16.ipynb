hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H48_6_6_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H48_2_5_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_12_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_3_4_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H46_11_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_13_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_9_12_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H20_4_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H48_6_7_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_6_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_27_5_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_30_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_8_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_10_12_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_20_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_6_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_12_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H20_6_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_h3_18_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_3_6_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_2_8_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_7_5_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H20_11_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_21_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H9_19_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_21_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H1_19_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_33_4_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H1_1_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_9_17_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_7_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_7_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_20_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H20_2_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H18_6_5_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_6_5_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H46_2_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H9_25_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_10_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H20_28_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_9_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_22_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_17_6_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_2_4_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_11_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H8_8_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_24_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_13_5_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_9_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_6_13_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_43_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_10_13_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_14_5_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H5_12_4_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H8_2_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_21_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_19_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_26_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_18_13_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_8_7_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H48_6_4_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_20_4_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_12_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_24_12_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H9_33_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H48_16_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H18_4_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_8_9_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_1_5_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H20_20_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_11_5_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_49_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H9_11_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H48_16_8_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_9_8_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_36_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H20_7_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_20_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_29_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_35_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_6_9_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_19_5_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_h3_31_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H20_19_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H40_24_13_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H18_10_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_11_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_2_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H9_21_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_13_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H5_2_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H48_10_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_44_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H20_13_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H46_22_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H13_13_1_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H5_11_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H23_19_8_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H48_10_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_33_2_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H2_38_3_hem.bmp
# /kaggle/input/cnmc-leukemia/fold_2/fold_2/hem/UID_H48_16_10_hem.bmp

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# VGG16
from keras.applications.vgg16 import VGG16

# To show images
from PIL import Image

# %%
# Collect all data into one dataframe
def create_df(dataset):
    image_paths, labels = [], []

    for dirpath, dirnames, filenames in os.walk(dataset):
        for filename in filenames:

            image = os.path.join(dirpath, filename)
            image_paths.append(image)
            if dirpath[-3:] == 'all':
                labels.append('all')
            else:
                labels.append('hem')
                
    df = pd.DataFrame({'Image Path': image_paths, 
                           'Label': labels}) 
    
    return df


train_dir = "/kaggle/input/cnmc-leukemia/fold_0"
df =  create_df(train_dir)

train_df, remaining_df = train_test_split(df, train_size=0.7, shuffle=True, random_state=31, stratify=df['Label'])
valid_df, test_df= train_test_split(remaining_df, train_size=0.5, shuffle=True, random_state=31, stratify=remaining_df['Label'])

print("Number of training samples: %d" % len(train_df.index))
print("Number of test samples: %d" % len(test_df.index))
print("Number of validation samples: %d" % len(valid_df.index))
# Out:
# Number of training samples: 2468
# Number of test samples: 530
# Number of validation samples: 529

# %%
def show_history_plot(history):

    training_accuracy = history['accuracy']
    epochs = range(1, len(training_accuracy) + 1)

    # Creating subplots for accuracy and loss
    plt.figure(figsize=(15, 5))

    # Plotting training and validation accuracy
    plt.subplot(1, 2, 1)  # 1 row, 2 columns, first plot
    plt.plot(epochs, history['accuracy'], 'b', label='Training accuracy', marker='o')
    plt.plot(epochs, history['val_accuracy'], 'c', label='Validation accuracy', marker='o')
    plt.title('Training and Validation Accuracy', fontsize=14)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend()
    plt.grid(True)

    # Plotting training and validation loss
    plt.subplot(1, 2, 2)  # 1 row, 2 columns, second plot
    plt.plot(epochs, history['loss'], 'b', label='Training loss', marker='o')
    plt.plot(epochs, history['val_loss'], 'c', label='Validation loss', marker='o')
    plt.title('Training and Validation Loss', fontsize=14)
    plt.xlabel('Epochs', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend()
    plt.grid(True)

    # Improve layout and displaying the plot
    plt.tight_layout()
    plt.show()

# %%
def show_conf_matrix(model):
    test_gen.reset()  # Reset the generator to be sure it's at the start of the dataset
    y_pred = model.predict(test_gen, steps=test_gen.n // test_gen.batch_size+1, verbose=0)

    label_dict = test_gen.class_indices
    classes = list(label_dict.keys())

    # Convert predictions to labels
    pred_labels = np.argmax(y_pred, axis=1)  
    y_true = test_gen.classes  
    
    # Generate the confusion matrix
    confusion_matrix = metrics.confusion_matrix(y_true, pred_labels)
    cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=[False, True])

    # Plot the confusion matrix 
    cmap = plt.cm.Blues
    cm_display.plot(cmap=cmap, colorbar=False)  
    
    plt.title('Confusion Matrix', fontsize=16)
    plt.figure(figsize=(7, 7)) 
    plt.show()

# %%
def evaluation_matrix(model):
    test_steps = len(test_df) // batch_size
    train_score = model.evaluate(train_gen, steps= test_steps, verbose= 0)
    valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 0)
    test_score = model.evaluate(test_gen, steps= test_steps, verbose= 0)

    header = "{:<12} {:<10} {:<10}".format("", "Loss", "Accuracy") 
    separator = '-' * len(header)
    train_row = "{:<12} {:<10.5f} {:<10.5f}".format("Train", train_score[0], train_score[1])  # Formats the float to five decimal places
    valid_row = "{:<12} {:<10.5f} {:<10.5f}".format("Validation", valid_score[0], valid_score[1])
    test_row = "{:<12} {:<10.5f} {:<10.5f}".format("Test", test_score[0], test_score[1])

    table = '\n'.join([header, separator, train_row, valid_row, test_row])
    print(table)

# %%
hem_img = train_df[train_df['Label'] == 'hem'].sample(3)
all_img = train_df[train_df['Label'] == 'all'].sample(3)
sampled_df = pd.concat([hem_img, all_img])

# Create a figure with subplots to show the images in
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12, 6))

for i, row in enumerate(sampled_df.iterrows()):
    img = mpimg.imread(row[1]['Image Path'])
    ax = axes[i//3, i%3]
    ax.imshow(img)
    ax.axis('off')    
    if row[1]['Label'] == 'hem':
        ax.set_title(f"Label: hem")
    else:
        ax.set_title(f"Label: all")

plt.show()

# %%
batch_size = 40

train_data_generator = ImageDataGenerator(horizontal_flip=True)
valid_data_generator = ImageDataGenerator()

train_gen = train_data_generator.flow_from_dataframe( train_df, x_col= 'Image Path', y_col= 'Label', target_size= (224, 224), class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

valid_gen = valid_data_generator.flow_from_dataframe( valid_df, x_col= 'Image Path', y_col= 'Label', target_size= (224, 224), class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

test_gen = valid_data_generator.flow_from_dataframe( test_df, x_col= 'Image Path', y_col= 'Label', target_size= (224, 224), class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= False, batch_size= batch_size)

train_steps = test_gen.n // test_gen.batch_size + 1
validation_steps = valid_gen.n // valid_gen.batch_size
# Out:
# Found 2468 validated image filenames belonging to 2 classes.
# Found 529 validated image filenames belonging to 2 classes.
# Found 530 validated image filenames belonging to 2 classes.

# %%
# Instantiate base model
img_shape=(224, 224, 3)
VGG16_base_model = VGG16(weights='imagenet', input_shape=img_shape, include_top=False, pooling=None)

# Freeze base model to keep pre-trained weights
VGG16_base_model.trainable = False

# Add custom top layers for binary classification
last_layer = VGG16_base_model.get_layer('block5_pool')
last_output = last_layer.output
x = keras.layers.GlobalMaxPooling2D()(last_output)
x = keras.layers.Dropout(0.5)(x)
x = keras.layers.Dense(2, activation='sigmoid')(x) 

# Create new model
VGG16_model = tf.keras.Model(VGG16_base_model.input, x, name="VGG16_model")

VGG16_model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

VGG16_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "VGG16_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d            │ (None, 512)            │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │         1,026 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,715,714 (56.14 MB)
#  Trainable params: 1,026 (4.01 KB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
epochs = 20

history_VGG16 = VGG16_model.fit(
    train_gen,
    steps_per_epoch=train_steps,
    validation_data=valid_gen,
    validation_steps=validation_steps,
    epochs=epochs,
    batch_size=batch_size,
    verbose=1
)
# Out:
# Epoch 1/20
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734335697.098179      71 service.cc:145] XLA service 0x7baa7000ba60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00: